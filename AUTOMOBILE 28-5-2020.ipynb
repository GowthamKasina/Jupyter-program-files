# %% [markdown]
# # AUTOMOBILE 28-5-2020

# %%
# missing value
# identify the missing value
# lets us work with the missing value
# correct data format
# Data standardization
# Binning
# Indicator values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv")
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
df.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
headers = ["symboling","normalized_losses","make","fuel_type", "aspiration", "num_of_doors","body_style","drive_wheels"

"engine_location","wheel_base","length","width","height", "curb_weight", "engine_type","No_of_cylinders", "engine_size",

"fuel_system" ,"bore","stroke","compression_ratio","horsepower", "peak_rpm","city_mpg", "highway_mpg","price"]

# %%
df = pd.read_csv(url,names = headers)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3         ?       alfa-romero     gas       std        two  convertible
#  3         ?       alfa-romero     gas       std        two  convertible
#  1         ?       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
#How to deal with these missing values
#replace(A,B,inplace = True)
# i will replace b with a
df.replace('?',np.nan,inplace = True)
df.head(50)
# Out:
#    symboling normalized_losses make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero  gas       std        two  convertible
#  3       NaN       alfa-romero  gas       std        two  convertible
#  1       NaN       alfa-romero  gas       std        two    hatchback
#  2       164              audi  gas       std       four        sedan
#  2       164              audi  gas       std       four        sedan
#  2       NaN              audi  gas       std        two        sedan
#  1       158              audi  gas       std       four        sedan
#  1       NaN              audi  gas       std       four        wagon
#  1       158              audi  gas     turbo       four        sedan
#  0       NaN              audi  gas     turbo        two    hatchback
#  2       192               bmw  gas       std        two        sedan
#  0       192               bmw  gas       std       four        sedan
# ...

# %%
#How to deal with these missing values
#replace(A,B,inplace = True)
# i will replace b with a
df.replace('?',np.nan,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
# Method2
# isnull()
# notnull()
missing_data = df.isnull()
missing_data
# True stands for missing value and False stands for not missing value
# Out:
#     symboling  normalized_losses   make  fuel_type  aspiration  num_of_doors  \
#  3       True              False  False      False       False         False
#  3       True              False  False      False       False         False
#  1       True              False  False      False       False         False
#  2      False              False  False      False       False         False
#  2      False              False  False      False       False         False
# ..        ...                ...    ...        ...         ...           ...
# -1      False              False  False      False       False         False
# -1      False              False  False      False       False         False
# -1      False              False  False      False       False         False
# -1      False              False  False      False       False         False
# -1      False              False  False      False       False         False
#
# ...

# %%
#How many missing values are presented in each column
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    164
# True      41
# Name: symboling, dtype: int64
#
# normalized_losses
# False    205
# Name: normalized_losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel_type
# False    205
# Name: fuel_type, dtype: int64
#
# aspiration
# False    203
# True       2
# Name: aspiration, dtype: int64
#
# num_of_doors
# False    205
# Name: num_of_doors, dtype: int64
#
# body_style
# False    205
# Name: body_style, dtype: int64
#
# drive_wheelsengine_location
# False    205
# Name: drive_wheelsengine_location, dtype: int64
#
# wheel_base
# False    205
# Name: wheel_base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb_weight
# False    205
# Name: curb_weight, dtype: int64
#
# engine_type
# False    205
# Name: engine_type, dtype: int64
#
# No_of_cylinders
# False    205
# Name: No_of_cylinders, dtype: int64
#
# ...

# %%
# normalized losses = 44 missing data
# num of door  = 2 missing data
# bore = 4 missing data
# horse power = 2
# peak_rpm = 2
# price = 4 missing data
# stroke = 4 missing data

# %%
# how to deal with these missing data 
# Replace by mean

# normalized losses = 44 missing data
# bore = 4 missing data
# horse power = 2
# peak_rpm = 2
# price = 4 missing data
# stroke = 4 missing data
# replace by frequency

# num of door  = 2 missing data
# drop the whole row

# %%
# Replace the mean of the columns
norma_loss = df['normalized_losses'].astype('float').mean(axis = 0)
norma_loss
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-04ffcbe65804> in <module>
#       1 # Replace the mean of the columns
# ----> 2 norma_loss = df['normalized_losses'].astype('float').mean(axis = 0)
#       3 norma_loss
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
# ...

# %%
# Replace nan by mean in the normalized_losses
df['normalized_losses'].replace(np.nan,norma_loss,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
bor = df['bore'].astype('float').mean(axis = 0)
bor
# Out:
# 3.3297512437810957

# %%
# Replace nan by mean in the bore
df['bore'].replace(np.nan,bor,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
hp = df['horsepower'].astype('float').mean(axis = 0)
hp
# Out:
# 104.25615763546799

# %%
# Replace nan by mean in the horsepower
df['horsepower'].replace(np.nan,hp,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
rpm = df['peak_rpm'].astype('float').mean(axis = 0)
rpm
# Out:
# 5125.369458128079

# %%
# Replace nan by mean in the horsepower
df['peak_rpm'].replace(np.nan,rpm,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
p = df['price'].astype('float').mean(axis = 0)
p
# Out:
# 13207.129353233831

# %%
# Replace nan by mean in the price
df['price'].replace(np.nan,p,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
srk = df['stroke'].astype('float').mean(axis = 0)
srk
# Out:
# 3.2554228855721337

# %%
# Replace nan by mean in the stroke
df['stroke'].replace(np.nan,srk,inplace = True)
df
# Out:
#    symboling normalized_losses    make fuel_type aspiration num_of_doors  \
#  3       NaN       alfa-romero     gas       std        two  convertible
#  3       NaN       alfa-romero     gas       std        two  convertible
#  1       NaN       alfa-romero     gas       std        two    hatchback
#  2       164              audi     gas       std       four        sedan
#  2       164              audi     gas       std       four        sedan
# ..       ...               ...     ...       ...        ...          ...
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    body_style drive_wheelsengine_location  wheel_base  length  ...  \
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 85      5
# 168     5
# 102     5
# 74      5
# 103     5
# 65      5
# 95      5
# 94      5
# 148     4
# 106     4
# 93      4
# 118     4
# 122     4
# 101     3
# 137     3
# 125     3
# 154     3
# 115     3
# 83      3
# 194     2
# 158     2
# 87      2
# 129     2
# 110     2
# 197     2
# 108     2
# 119     2
# 145     2
# 192     2
# 113     2
# 81      2
# 153     2
# 188     2
# 164     2
# 89      2
# 78      1
# 107     1
# 98      1
# 142     1
# 231     1
# 186     1
# 90      1
# 77      1
# 121     1
# 256     1
# Name: symboling, dtype: int64
#
# normalized_losses
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              7
# ...
